# %%
data = [22,25,65,65,45,69,56,45,66,55,99,14,63,51,35,65,66,15,65,56,45,67]
print(data)
# Out:
# [22, 25, 65, 65, 45, 69, 56, 45, 66, 55, 99, 14, 63, 51, 35, 65, 66, 15, 65, 56, 45, 67]

# %%
import numpy as np

grades = np.array(data)
print(data)
# Out:
# [22, 25, 65, 65, 45, 69, 56, 45, 66, 55, 99, 14, 63, 51, 35, 65, 66, 15, 65, 56, 45, 67]

# %%
print(type(data), 'x 2', data * 2)
# Out:
# <class 'list'> x 2 [22, 25, 65, 65, 45, 69, 56, 45, 66, 55, 99, 14, 63, 51, 35, 65, 66, 15, 65, 56, 45, 67, 22, 25, 65, 65, 45, 69, 56, 45, 66, 55, 99, 14, 63, 51, 35, 65, 66, 15, 65, 56, 45, 67]

# %%
print(type(grades), 'x 2', grades * 2)
# Out:
# <class 'numpy.ndarray'> x 2 [ 44  50 130 130  90 138 112  90 132 110 198  28 126 102  70 130 132  30
#  130 112  90 134]

# %%
grades.shape
# Out:
# (22,)

# %%
grades[0]
# Out:
# 22

# %%
grades.mean()
# Out:
# 52.45454545454545

# %%
study_hour = [10.0,11.5,9.0,16.0,9.25,1.0,11.5,9.0,8.5,14.5,15.5,13.75,9.0,8.0,15.5,8.0,9.0,6.0,10.0,12.0,12.5,12.0]
student_data = np.array([study_hour, grades])

student_data
# Out:
# array([[10.  , 11.5 ,  9.  , 16.  ,  9.25,  1.  , 11.5 ,  9.  ,  8.5 ,
#         14.5 , 15.5 , 13.75,  9.  ,  8.  , 15.5 ,  8.  ,  9.  ,  6.  ,
#         10.  , 12.  , 12.5 , 12.  ],
#        [22.  , 25.  , 65.  , 65.  , 45.  , 69.  , 56.  , 45.  , 66.  ,
#         55.  , 99.  , 14.  , 63.  , 51.  , 35.  , 65.  , 66.  , 15.  ,
#         65.  , 56.  , 45.  , 67.  ]])

# %%
student_data.shape
# Out:
# (2, 22)

# %%
student_data[0][0]
# Out:
# 10.0

# %%
avg_study = student_data[0].mean()
avg_grade = student_data[1].mean()

print('Average study hour: {:.2f}\nAverage Grade: {:.2f}'.format(avg_study, avg_grade))
# Out:
# Average study hour: 10.52
# Average Grade: 52.45

# %%
import pandas as pd

df_students = pd.DataFrame({'Name': ['Dan', 'Joann', 'Pedro', 'Rosie', 'Ethan', 'Vicky', 'Frederic', 'Jimmie', 
                                     'Rhonda', 'Giovanni', 'Francesca', 'Rajab', 'Naiyana', 'Kian', 'Jenny',
                                     'Jakeem','Helena','Ismat','Anila','Skye','Daniel','Aisha'],
                            'StudyHours':student_data[0],
                            'Grade':student_data[1]})
df_students
# Out:
#          Name  StudyHours  Grade
# 0         Dan       10.00   22.0
# 1       Joann       11.50   25.0
# 2       Pedro        9.00   65.0
# 3       Rosie       16.00   65.0
# 4       Ethan        9.25   45.0
# 5       Vicky        1.00   69.0
# 6    Frederic       11.50   56.0
# 7      Jimmie        9.00   45.0
# 8      Rhonda        8.50   66.0
# 9    Giovanni       14.50   55.0
# 10  Francesca       15.50   99.0
# 11      Rajab       13.75   14.0
# 12    Naiyana        9.00   63.0
# 13       Kian        8.00   51.0
# 14      Jenny       15.50   35.0
# 15     Jakeem        8.00   65.0
# 16     Helena        9.00   66.0
# 17      Ismat        6.00   15.0
# 18      Anila       10.00   65.0
# 19       Skye       12.00   56.0
# 20     Daniel       12.50   45.0
# 21      Aisha       12.00   67.0

# %%
df_students.loc[5]
# Out:
# Name          Vicky
# StudyHours      1.0
# Grade          69.0
# Name: 5, dtype: object

# %%
df_students.loc[0:5]
# Out:
#     Name  StudyHours  Grade
# 0    Dan       10.00   22.0
# 1  Joann       11.50   25.0
# 2  Pedro        9.00   65.0
# 3  Rosie       16.00   65.0
# 4  Ethan        9.25   45.0
# 5  Vicky        1.00   69.0

# %%
df_students.iloc[0:5]
# Out:
#     Name  StudyHours  Grade
# 0    Dan       10.00   22.0
# 1  Joann       11.50   25.0
# 2  Pedro        9.00   65.0
# 3  Rosie       16.00   65.0
# 4  Ethan        9.25   45.0

# %%
df_students.iloc[0,[1,2]]
# Out:
# StudyHours    10.0
# Grade         22.0
# Name: 0, dtype: object

# %%
df_students.loc[0, 'Grade']
# Out:
# 22.0

# %%
df_students.loc[df_students['Name'] == 'Aisha']
# Out:
#      Name  StudyHours  Grade
# 21  Aisha        12.0   67.0

# %%
df_students[df_students['Name'] == 'Aisha']
# Out:
#      Name  StudyHours  Grade
# 21  Aisha        12.0   67.0

# %%
df_students.query('Name == "Aisha"')
# Out:
#      Name  StudyHours  Grade
# 21  Aisha        12.0   67.0

# %%
df_students[df_students.Name == 'Aisha']
# Out:
#      Name  StudyHours  Grade
# 21  Aisha        12.0   67.0

# %%
# !wget https://raw.githubusercontent.com/MicrosoftDocs/mslearn-introduction-to-machine-learning/main/Data/ml-basics/grades.csv
df_students = pd.read_csv('grades.csv', delimiter=',', header='infer')
# Out:
# --2022-12-02 06:13:33--  https://raw.githubusercontent.com/MicrosoftDocs/mslearn-introduction-to-machine-learning/main/Data/ml-basics/grades.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 322 [text/plain]
# Saving to: ‘grades.csv’
#
# grades.csv          100%[===================>]     322  --.-KB/s    in 0s
#
# 2022-12-02 06:13:33 (9.45 MB/s) - ‘grades.csv’ saved [322/322]

# %%
df_students.head()
# Out:
#     Name  StudyHours  Grade
# 0    Dan       10.00   50.0
# 1  Joann       11.50   50.0
# 2  Pedro        9.00   47.0
# 3  Rosie       16.00   97.0
# 4  Ethan        9.25   49.0

# %%
df_students.tail()
# Out:
#       Name  StudyHours  Grade
# 19    Skye        12.0   52.0
# 20  Daniel        12.5   63.0
# 21   Aisha        12.0   64.0
# 22    Bill         8.0    NaN
# 23     Ted         NaN    NaN

# %%
df_students.isnull()
# Out:
#      Name  StudyHours  Grade
# 0   False       False  False
# 1   False       False  False
# 2   False       False  False
# 3   False       False  False
# 4   False       False  False
# 5   False       False  False
# 6   False       False  False
# 7   False       False  False
# 8   False       False  False
# 9   False       False  False
# 10  False       False  False
# 11  False       False  False
# 12  False       False  False
# 13  False       False  False
# 14  False       False  False
# 15  False       False  False
# 16  False       False  False
# 17  False       False  False
# 18  False       False  False
# 19  False       False  False
# 20  False       False  False
# 21  False       False  False
# 22  False       False   True
# 23  False        True   True

# %%
df_students.isnull().sum()
# Out:
# Name          0
# StudyHours    1
# Grade         2
# dtype: int64

# %%
df_students[df_students.isnull().any(axis=1)]
# Out:
#     Name  StudyHours  Grade
# 22  Bill         8.0    NaN
# 23   Ted         NaN    NaN

# %%
df_students.StudyHours = df_students.StudyHours.fillna(df_students.StudyHours.mean())
df_students
# Out:
#          Name  StudyHours  Grade
# 0         Dan   10.000000   50.0
# 1       Joann   11.500000   50.0
# 2       Pedro    9.000000   47.0
# 3       Rosie   16.000000   97.0
# 4       Ethan    9.250000   49.0
# 5       Vicky    1.000000    3.0
# 6    Frederic   11.500000   53.0
# 7      Jimmie    9.000000   42.0
# 8      Rhonda    8.500000   26.0
# 9    Giovanni   14.500000   74.0
# 10  Francesca   15.500000   82.0
# 11      Rajab   13.750000   62.0
# 12    Naiyana    9.000000   37.0
# 13       Kian    8.000000   15.0
# 14      Jenny   15.500000   70.0
# 15     Jakeem    8.000000   27.0
# 16     Helena    9.000000   36.0
# 17      Ismat    6.000000   35.0
# 18      Anila   10.000000   48.0
# 19       Skye   12.000000   52.0
# 20     Daniel   12.500000   63.0
# 21      Aisha   12.000000   64.0
# 22       Bill    8.000000    NaN
# 23        Ted   10.413043    NaN

# %%
df_students = df_students.dropna(axis=0, how='any')
df_students
# Out:
#          Name  StudyHours  Grade
# 0         Dan       10.00   50.0
# 1       Joann       11.50   50.0
# 2       Pedro        9.00   47.0
# 3       Rosie       16.00   97.0
# 4       Ethan        9.25   49.0
# 5       Vicky        1.00    3.0
# 6    Frederic       11.50   53.0
# 7      Jimmie        9.00   42.0
# 8      Rhonda        8.50   26.0
# 9    Giovanni       14.50   74.0
# 10  Francesca       15.50   82.0
# 11      Rajab       13.75   62.0
# 12    Naiyana        9.00   37.0
# 13       Kian        8.00   15.0
# 14      Jenny       15.50   70.0
# 15     Jakeem        8.00   27.0
# 16     Helena        9.00   36.0
# 17      Ismat        6.00   35.0
# 18      Anila       10.00   48.0
# 19       Skye       12.00   52.0
# 20     Daniel       12.50   63.0
# 21      Aisha       12.00   64.0

# %%
mean_study = df_students['StudyHours'].mean()

mean_grade = df_students.Grade.mean()

print('Average study hour: {:.2f}\nAverage Grade: {:.2f}'.format(avg_study, avg_grade))
# Out:
# Average study hour: 10.52
# Average Grade: 52.45

# %%
df_students[df_students.StudyHours > mean_study]
# Out:
#          Name  StudyHours  Grade
# 1       Joann       11.50   50.0
# 3       Rosie       16.00   97.0
# 6    Frederic       11.50   53.0
# 9    Giovanni       14.50   74.0
# 10  Francesca       15.50   82.0
# 11      Rajab       13.75   62.0
# 14      Jenny       15.50   70.0
# 19       Skye       12.00   52.0
# 20     Daniel       12.50   63.0
# 21      Aisha       12.00   64.0

# %%
df_students[df_students.StudyHours > mean_study].Grade.mean()
# Out:
# 66.7

# %%
passes = pd.Series(df_students['Grade'] >=60)
df_students = pd.concat([df_students , passes.rename("Pass")], axis=1)
df_students
# Out:
#          Name  StudyHours  Grade   Pass
# 0         Dan       10.00   50.0  False
# 1       Joann       11.50   50.0  False
# 2       Pedro        9.00   47.0  False
# 3       Rosie       16.00   97.0   True
# 4       Ethan        9.25   49.0  False
# 5       Vicky        1.00    3.0  False
# 6    Frederic       11.50   53.0  False
# 7      Jimmie        9.00   42.0  False
# 8      Rhonda        8.50   26.0  False
# 9    Giovanni       14.50   74.0   True
# 10  Francesca       15.50   82.0   True
# 11      Rajab       13.75   62.0   True
# 12    Naiyana        9.00   37.0  False
# 13       Kian        8.00   15.0  False
# 14      Jenny       15.50   70.0   True
# 15     Jakeem        8.00   27.0  False
# 16     Helena        9.00   36.0  False
# 17      Ismat        6.00   35.0  False
# 18      Anila       10.00   48.0  False
# 19       Skye       12.00   52.0  False
# 20     Daniel       12.50   63.0   True
# 21      Aisha       12.00   64.0   True

# %%
print(df_students.groupby(df_students.Pass).Name.count())
# Out:
# Pass
# False    15
# True      7
# Name: Name, dtype: int64

# %%
print(df_students.groupby(df_students.Pass)['StudyHours', 'Grade'].mean())
# Out:
#        StudyHours      Grade
# Pass
# False    8.783333  38.000000
# True    14.250000  73.142857
# /tmp/ipykernel_8609/2502225861.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   print(df_students.groupby(df_students.Pass)['StudyHours', 'Grade'].mean())

# %%
df_students = df_students.sort_values('Grade', ascending=False)
df_students
# Out:
#          Name  StudyHours  Grade   Pass
# 3       Rosie       16.00   97.0   True
# 10  Francesca       15.50   82.0   True
# 9    Giovanni       14.50   74.0   True
# 14      Jenny       15.50   70.0   True
# 21      Aisha       12.00   64.0   True
# 20     Daniel       12.50   63.0   True
# 11      Rajab       13.75   62.0   True
# 6    Frederic       11.50   53.0  False
# 19       Skye       12.00   52.0  False
# 1       Joann       11.50   50.0  False
# 0         Dan       10.00   50.0  False
# 4       Ethan        9.25   49.0  False
# 18      Anila       10.00   48.0  False
# 2       Pedro        9.00   47.0  False
# 7      Jimmie        9.00   42.0  False
# 12    Naiyana        9.00   37.0  False
# 16     Helena        9.00   36.0  False
# 17      Ismat        6.00   35.0  False
# 15     Jakeem        8.00   27.0  False
# 8      Rhonda        8.50   26.0  False
# 13       Kian        8.00   15.0  False
# 5       Vicky        1.00    3.0  False
